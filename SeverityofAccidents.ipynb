# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Accident_train.csv")

# %%
for i in range(17):
  print("The no of Null Values in column",i,"are:")
  nullcheck=df.iloc[:,i].isnull().sum()
  print(nullcheck)
# Out:
# The no of Null Values in column 0 are:
# 0
# The no of Null Values in column 1 are:
# 334
# The no of Null Values in column 2 are:
# 0
# The no of Null Values in column 3 are:
# 0
# The no of Null Values in column 4 are:
# 0
# The no of Null Values in column 5 are:
# 0
# The no of Null Values in column 6 are:
# 284
# The no of Null Values in column 7 are:
# 0
# The no of Null Values in column 8 are:
# 0
# The no of Null Values in column 9 are:
# 293
# The no of Null Values in column 10 are:
# 299
# The no of Null Values in column 11 are:
# 321
# The no of Null Values in column 12 are:
# 300
# The no of Null Values in column 13 are:
# 0
# The no of Null Values in column 14 are:
# 0
# The no of Null Values in column 15 are:
# 309
# The no of Null Values in column 16 are:
# 288

# %%
df=df.dropna()
df
# Out:
#        Collision_Ref_No Policing_Area  Collision_Severity  \
# 0                  3518          CREA                   3
# 1                 10557          BELC                   3
# 2                  5002          LISB                   3
# 4                 12416          MIDU                   3
# 5                   558          FOYL                   2
# ...                 ...           ...                 ...
# 10035             11254          ARND                   3
# 10038              3535          LISB                   3
# 10039             11675          ARND                   3
# 10040              7222          ARND                   3
# 10041             12320          BELC                   3
#
#       Weekday_of_Collision  Day_of_Collision  Month_of_Collision  \
# 0                      MON                 4                   8
# 1                      SAT                 8                   8
# 2                      WED                 5                  11
# 4                      MON                23                  11
# 5                      MON                 3                   2
# ...                    ...               ...                 ...
# 10035                  TUE                22                   9
# 10038                  TUE                 5                   8
# 10039                  FRI                16                  10
# 10040                  FRI                16                   1
# 10041                  WED                18                  11
#
#        Hour_of_Collision  Carriageway_Type  Speed_Limit  Junction_Detail  \
# 0                   14.0                13           60              1.0
# 1                   17.0                11           50             12.0
# 2                   17.0                 1           60             12.0
# 4                    9.0                13           60              6.0
# 5                   12.0                13           60              1.0
# ...                  ...               ...          ...              ...
# 10035                9.0                13           60              1.0
# 10038               10.0                11           70             10.0
# 10039                8.0                13           30              1.0
# 10040                9.0                13           60             12.0
# 10041               20.0                13           30             12.0
#
#        Junction_Control  Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  \
# 0                   1.0              1.0              1.0                 2
# 1                   7.0              1.0              1.0                 4
# 2                   7.0              1.0              1.0                 2
# 4                   7.0              1.0              1.0                 2
# 5                   1.0              1.0              1.0                 2
# ...                 ...              ...              ...               ...
# 10035               1.0              1.0              9.0                 3
# 10038               7.0              1.0              1.0                 3
# 10039               1.0              1.0              1.0                 3
# 10040               7.0              1.0              1.0                 3
# 10041               7.0              1.0              1.0                 4
#
#        Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site
# 0                       9                      9.0                         1.0
# 1                       3                      1.0                         1.0
# 2                       2                      2.0                         1.0
# 4                       3                      1.0                         1.0
# 5                       2                      2.0                         1.0
# ...                   ...                      ...                         ...
# 10035                  10                      2.0                         1.0
# 10038                   9                      1.0                         1.0
# 10039                   1                      1.0                         1.0
# 10040                   2                      1.0                         1.0
# 10041                   9                      2.0                         1.0
#
# [7852 rows x 17 columns]

# %%
for i in range(17):
  print("The no of Null Values in column",i,"are:")
  nullcheck=df.iloc[:,i].isnull().sum()
  print(nullcheck)
# Out:
# The no of Null Values in column 0 are:
# 0
# The no of Null Values in column 1 are:
# 0
# The no of Null Values in column 2 are:
# 0
# The no of Null Values in column 3 are:
# 0
# The no of Null Values in column 4 are:
# 0
# The no of Null Values in column 5 are:
# 0
# The no of Null Values in column 6 are:
# 0
# The no of Null Values in column 7 are:
# 0
# The no of Null Values in column 8 are:
# 0
# The no of Null Values in column 9 are:
# 0
# The no of Null Values in column 10 are:
# 0
# The no of Null Values in column 11 are:
# 0
# The no of Null Values in column 12 are:
# 0
# The no of Null Values in column 13 are:
# 0
# The no of Null Values in column 14 are:
# 0
# The no of Null Values in column 15 are:
# 0
# The no of Null Values in column 16 are:
# 0

# %%
df.Hour_of_Collision.unique()
# Out:
# array([14., 17.,  9., 12., 16.,  8., 10., 15., 18., 13., 20., 19., 21.,
#         2.,  6., 22.,  7., 23., 11.,  5.,  0.,  1.,  4.,  3.])

# %%
df.Junction_Control.unique()
# Out:
# array([1., 7., 3., 4.])

# %%
df=df.reset_index(drop=True)
df
# Out:
#       Collision_Ref_No Policing_Area  Collision_Severity Weekday_of_Collision  \
# 0                 3518          CREA                   3                  MON
# 1                10557          BELC                   3                  SAT
# 2                 5002          LISB                   3                  WED
# 3                12416          MIDU                   3                  MON
# 4                  558          FOYL                   2                  MON
# ...                ...           ...                 ...                  ...
# 7847             11254          ARND                   3                  TUE
# 7848              3535          LISB                   3                  TUE
# 7849             11675          ARND                   3                  FRI
# 7850              7222          ARND                   3                  FRI
# 7851             12320          BELC                   3                  WED
#
#       Day_of_Collision  Month_of_Collision  Hour_of_Collision  \
# 0                    4                   8               14.0
# 1                    8                   8               17.0
# 2                    5                  11               17.0
# 3                   23                  11                9.0
# 4                    3                   2               12.0
# ...                ...                 ...                ...
# 7847                22                   9                9.0
# 7848                 5                   8               10.0
# 7849                16                  10                8.0
# 7850                16                   1                9.0
# 7851                18                  11               20.0
#
#       Carriageway_Type  Speed_Limit  Junction_Detail  Junction_Control  \
# 0                   13           60              1.0               1.0
# 1                   11           50             12.0               7.0
# 2                    1           60             12.0               7.0
# 3                   13           60              6.0               7.0
# 4                   13           60              1.0               1.0
# ...                ...          ...              ...               ...
# 7847                13           60              1.0               1.0
# 7848                11           70             10.0               7.0
# 7849                13           30              1.0               1.0
# 7850                13           60             12.0               7.0
# 7851                13           30             12.0               7.0
#
#       Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  Weather_Conditions  \
# 0                 1.0              1.0                 2                   9
# 1                 1.0              1.0                 4                   3
# 2                 1.0              1.0                 2                   2
# 3                 1.0              1.0                 2                   3
# 4                 1.0              1.0                 2                   2
# ...               ...              ...               ...                 ...
# 7847              1.0              9.0                 3                  10
# 7848              1.0              1.0                 3                   9
# 7849              1.0              1.0                 3                   1
# 7850              1.0              1.0                 3                   2
# 7851              1.0              1.0                 4                   9
#
#       Road_Surface_Conditions  Special_Conditions_at_Site
# 0                         9.0                         1.0
# 1                         1.0                         1.0
# 2                         2.0                         1.0
# 3                         1.0                         1.0
# 4                         2.0                         1.0
# ...                       ...                         ...
# 7847                      2.0                         1.0
# 7848                      1.0                         1.0
# 7849                      1.0                         1.0
# 7850                      1.0                         1.0
# 7851                      2.0                         1.0
#
# [7852 rows x 17 columns]

# %%
dummies1=pd.get_dummies(df['Weekday_of_Collision'])
dummies1
# Out:
#         FRI    MON    SAT    SUN    THU    TUE    WED
# 0     False   True  False  False  False  False  False
# 1     False  False   True  False  False  False  False
# 2     False  False  False  False  False  False   True
# 3     False   True  False  False  False  False  False
# 4     False   True  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 7847  False  False  False  False  False   True  False
# 7848  False  False  False  False  False   True  False
# 7849   True  False  False  False  False  False  False
# 7850   True  False  False  False  False  False  False
# 7851  False  False  False  False  False  False   True
#
# [7852 rows x 7 columns]

# %%
dummies2=pd.get_dummies(df['Policing_Area'])
dummies2
# Out:
#        ANTN   ANTR   ARBC   ARDS   ARMA   ARND   BANB   BELC   BELE   BELN  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False   True  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7847  False  False  False  False  False   True  False  False  False  False
# 7848  False  False  False  False  False  False  False  False  False  False
# 7849  False  False  False  False  False   True  False  False  False  False
# 7850  False  False  False  False  False   True  False  False  False  False
# 7851  False  False  False  False  False  False  False   True  False  False
#
#       ...   MEAN   MFEL   MIDU   MOYL   NABB   NDOW   NEMD   NEWM   OMAG  \
# 0     ...  False  False  False  False  False  False  False  False  False
# 1     ...  False  False  False  False  False  False  False  False  False
# 2     ...  False  False  False  False  False  False  False  False  False
# 3     ...  False  False   True  False  False  False  False  False  False
# 4     ...  False  False  False  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7847  ...  False  False  False  False  False  False  False  False  False
# 7848  ...  False  False  False  False  False  False  False  False  False
# 7849  ...  False  False  False  False  False  False  False  False  False
# 7850  ...  False  False  False  False  False  False  False  False  False
# 7851  ...  False  False  False  False  False  False  False  False  False
#
#        STRB
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 7847  False
# 7848  False
# 7849  False
# 7850  False
# 7851  False
#
# [7852 rows x 40 columns]

# %%
df.drop(['Policing_Area','Weekday_of_Collision'],axis='columns',inplace=True)
df=pd.concat([df,dummies1,dummies2],axis='columns')
df
# Out:
#       Collision_Ref_No  Collision_Severity  Day_of_Collision  \
# 0                 3518                   3                 4
# 1                10557                   3                 8
# 2                 5002                   3                 5
# 3                12416                   3                23
# 4                  558                   2                 3
# ...                ...                 ...               ...
# 7847             11254                   3                22
# 7848              3535                   3                 5
# 7849             11675                   3                16
# 7850              7222                   3                16
# 7851             12320                   3                18
#
#       Month_of_Collision  Hour_of_Collision  Carriageway_Type  Speed_Limit  \
# 0                      8               14.0                13           60
# 1                      8               17.0                11           50
# 2                     11               17.0                 1           60
# 3                     11                9.0                13           60
# 4                      2               12.0                13           60
# ...                  ...                ...               ...          ...
# 7847                   9                9.0                13           60
# 7848                   8               10.0                11           70
# 7849                  10                8.0                13           30
# 7850                   1                9.0                13           60
# 7851                  11               20.0                13           30
#
#       Junction_Detail  Junction_Control  Ped_Crossing_HC  ...   MEAN   MFEL  \
# 0                 1.0               1.0              1.0  ...  False  False
# 1                12.0               7.0              1.0  ...  False  False
# 2                12.0               7.0              1.0  ...  False  False
# 3                 6.0               7.0              1.0  ...  False  False
# 4                 1.0               1.0              1.0  ...  False  False
# ...               ...               ...              ...  ...    ...    ...
# 7847              1.0               1.0              1.0  ...  False  False
# 7848             10.0               7.0              1.0  ...  False  False
# 7849              1.0               1.0              1.0  ...  False  False
# 7850             12.0               7.0              1.0  ...  False  False
# 7851             12.0               7.0              1.0  ...  False  False
#
#        MIDU   MOYL   NABB   NDOW   NEMD   NEWM   OMAG   STRB
# 0     False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False
# 3      True  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 7847  False  False  False  False  False  False  False  False
# 7848  False  False  False  False  False  False  False  False
# 7849  False  False  False  False  False  False  False  False
# 7850  False  False  False  False  False  False  False  False
# 7851  False  False  False  False  False  False  False  False
#
# [7852 rows x 62 columns]

# %%
Y=df['Collision_Severity']
Y.unique()
# Out:
# array([3, 2, 1])

# %%
X=df.drop(['Collision_Severity','Collision_Ref_No'],axis='columns')
X
# Out:
#       Day_of_Collision  Month_of_Collision  Hour_of_Collision  \
# 0                    4                   8               14.0
# 1                    8                   8               17.0
# 2                    5                  11               17.0
# 3                   23                  11                9.0
# 4                    3                   2               12.0
# ...                ...                 ...                ...
# 7847                22                   9                9.0
# 7848                 5                   8               10.0
# 7849                16                  10                8.0
# 7850                16                   1                9.0
# 7851                18                  11               20.0
#
#       Carriageway_Type  Speed_Limit  Junction_Detail  Junction_Control  \
# 0                   13           60              1.0               1.0
# 1                   11           50             12.0               7.0
# 2                    1           60             12.0               7.0
# 3                   13           60              6.0               7.0
# 4                   13           60              1.0               1.0
# ...                ...          ...              ...               ...
# 7847                13           60              1.0               1.0
# 7848                11           70             10.0               7.0
# 7849                13           30              1.0               1.0
# 7850                13           60             12.0               7.0
# 7851                13           30             12.0               7.0
#
#       Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  ...   MEAN   MFEL  \
# 0                 1.0              1.0                 2  ...  False  False
# 1                 1.0              1.0                 4  ...  False  False
# 2                 1.0              1.0                 2  ...  False  False
# 3                 1.0              1.0                 2  ...  False  False
# 4                 1.0              1.0                 2  ...  False  False
# ...               ...              ...               ...  ...    ...    ...
# 7847              1.0              9.0                 3  ...  False  False
# 7848              1.0              1.0                 3  ...  False  False
# 7849              1.0              1.0                 3  ...  False  False
# 7850              1.0              1.0                 3  ...  False  False
# 7851              1.0              1.0                 4  ...  False  False
#
#        MIDU   MOYL   NABB   NDOW   NEMD   NEWM   OMAG   STRB
# 0     False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False
# 3      True  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 7847  False  False  False  False  False  False  False  False
# 7848  False  False  False  False  False  False  False  False
# 7849  False  False  False  False  False  False  False  False
# 7850  False  False  False  False  False  False  False  False
# 7851  False  False  False  False  False  False  False  False
#
# [7852 rows x 60 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8,random_state=10)
X_train
# Out:
#       Day_of_Collision  Month_of_Collision  Hour_of_Collision  \
# 4961                 6                   8               18.0
# 22                   5                  12               19.0
# 3357                30                   3                0.0
# 7153                12                   1               14.0
# 6979                20                   7               19.0
# ...                ...                 ...                ...
# 3441                 5                   4               14.0
# 1344                20                  12               14.0
# 4623                10                  11               14.0
# 7293                31                   1               17.0
# 1289                27                   4               14.0
#
#       Carriageway_Type  Speed_Limit  Junction_Detail  Junction_Control  \
# 4961                12           70              1.0               1.0
# 22                  13           30             12.0               7.0
# 3357                13           30             12.0               7.0
# 7153                11           40             12.0               7.0
# 6979                13           60             12.0               3.0
# ...                ...          ...              ...               ...
# 3441                13           30              1.0               1.0
# 1344                13           60              1.0               1.0
# 4623                13           30              1.0               1.0
# 7293                13           30              1.0               1.0
# 1289                13           60              1.0               1.0
#
#       Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  ...   MEAN   MFEL  \
# 4961              1.0              1.0                 5  ...  False  False
# 22                1.0              1.0                 4  ...  False  False
# 3357              1.0              1.0                 7  ...  False  False
# 7153              1.0              1.0                 1  ...  False  False
# 6979              1.0             11.0                 4  ...  False  False
# ...               ...              ...               ...  ...    ...    ...
# 3441              1.0             11.0                 2  ...  False  False
# 1344              1.0              1.0                 2  ...  False  False
# 4623              1.0              1.0                 1  ...  False  False
# 7293              1.0              1.0                 2  ...  False  False
# 1289              1.0              1.0                 2  ...  False  False
#
#        MIDU   MOYL   NABB   NDOW   NEMD   NEWM   OMAG   STRB
# 4961  False  False  False  False  False  False  False  False
# 22    False  False  False  False  False  False  False  False
# 3357  False  False  False  False  False  False  False  False
# 7153  False  False  False  False  False  False  False  False
# 6979  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 3441  False  False  False  False  False  False  False  False
# 1344  False  False  False  False  False  False  False  False
# 4623  False  False  False  False   True  False  False  False
# 7293  False  False  False  False  False  False  False  False
# 1289  False  False  False  False  False  False  False  False
#
# [6281 rows x 60 columns]

# %%
X_test
# Out:
#       Day_of_Collision  Month_of_Collision  Hour_of_Collision  \
# 4244                24                   6               16.0
# 766                  8                  11               15.0
# 4308                18                   3               14.0
# 2218                21                  11               14.0
# 742                 20                  10                9.0
# ...                ...                 ...                ...
# 1886                21                   9               22.0
# 6204                 4                   9               12.0
# 7442                19                   8               12.0
# 4801                13                   4               13.0
# 5700                30                   5               17.0
#
#       Carriageway_Type  Speed_Limit  Junction_Detail  Junction_Control  \
# 4244                13           40             12.0               7.0
# 766                 13           30             12.0               4.0
# 4308                13           30              1.0               1.0
# 2218                13           30              1.0               1.0
# 742                 13           30              1.0               1.0
# ...                ...          ...              ...               ...
# 1886                13           60             12.0               7.0
# 6204                13           30              6.0               7.0
# 7442                13           60              1.0               1.0
# 4801                13           30             10.0               7.0
# 5700                13           30             12.0               7.0
#
#       Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  ...   MEAN   MFEL  \
# 4244              1.0              1.0                 2  ...  False  False
# 766               1.0              1.0                 1  ...  False  False
# 4308              1.0              1.0                 2  ...  False  False
# 2218              1.0              1.0                 2  ...  False  False
# 742               1.0              1.0                 1  ...  False  False
# ...               ...              ...               ...  ...    ...    ...
# 1886              1.0              1.0                 6  ...  False  False
# 6204              1.0              1.0                 2  ...  False  False
# 7442              1.0              1.0                 3  ...  False  False
# 4801              1.0              1.0                 1  ...  False  False
# 5700              1.0              1.0                 3  ...  False  False
#
#        MIDU   MOYL   NABB   NDOW   NEMD   NEWM   OMAG   STRB
# 4244  False  False  False  False  False  False  False  False
# 766   False  False  False  False  False   True  False  False
# 4308  False  False  False  False  False  False  False  False
# 2218  False  False  False   True  False  False  False  False
# 742   False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 1886  False  False  False  False  False  False  False  False
# 6204  False  False  False  False  False   True  False  False
# 7442  False  False  False  False  False  False  False  False
# 4801  False  False  False  False  False  False  False  False
# 5700  False  False  False  False  False  False  False  False
#
# [1571 rows x 60 columns]

# %%
Y_train
# Out:
# 4961    3
# 22      3
# 3357    3
# 7153    3
# 6979    3
#        ..
# 3441    3
# 1344    3
# 4623    3
# 7293    3
# 1289    3
# Name: Collision_Severity, Length: 6281, dtype: int64

# %%
Y_test
# Out:
# 4244    3
# 766     3
# 4308    3
# 2218    3
# 742     3
#        ..
# 1886    2
# 6204    3
# 7442    3
# 4801    3
# 5700    3
# Name: Collision_Severity, Length: 1571, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
Y_predicted=dt.predict(X_test)
print("The first five predicted Values are:")
print(Y_predicted[0:5])
print("The first five Test Values are:")
print(np.array(Y_test[0:5]))
print(dt.score(X_test,Y_test))
# Out:
# The first five predicted Values are:
# [3 3 3 3 3]
# The first five Test Values are:
# [3 3 3 3 3]
# 0.8351368555060471

# %%
from sklearn import metrics
matrix=metrics.confusion_matrix(Y_predicted,Y_test)
sns.heatmap(matrix,cmap='Oranges',annot=True,fmt='0.1f')
plt.xlabel("Predicted values")
plt.ylabel("Test values")
plt.title("Confusion Matrix for DecisionTreeClassifier")
plt.show()

# %%
from sklearn.model_selection import cross_val_score
dt.fit(X,Y)
print(cross_val_score(dt,X,Y,cv=10))
print(np.average(cross_val_score(dt,X,Y,cv=10)))
# Out:
# [0.82697201 0.86513995 0.84968153 0.8522293  0.85987261 0.8522293
#  0.86496815 0.85605096 0.84968153 0.85477707]
# 0.8488317855464255
